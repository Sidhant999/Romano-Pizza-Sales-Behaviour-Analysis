# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('/content/pizza_sales_cleaned2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pizza_id        48620 non-null  int64
#  1   order_id        48620 non-null  int64
#  2   quantity        48620 non-null  int64
#  3   order_date      48620 non-null  object
#  4   order_time      48620 non-null  object
#  5   unit_price      48620 non-null  float64
#  6   total_price     48620 non-null  float64
#  7   pizza_size      48620 non-null  object
#  8   pizza_category  48620 non-null  object
#  9   pizza_name      48620 non-null  object
#  10  month           48620 non-null  int64
#  11  month_name      48620 non-null  object
#  12  day_of_week     48620 non-null  object
#  13  quarter         48620 non-null  int64
#  14  hour            48620 non-null  int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 5.6+ MB

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2907/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe(include="all")
# Out:
#             pizza_id      order_id      quantity  order_date order_time  \
# count   48620.000000  48620.000000  48620.000000       48620      48620
# unique           NaN           NaN           NaN         358      16382
# top              NaN           NaN           NaN  2015-11-26   12:32:00
# freq             NaN           NaN           NaN         261         26
# mean    24310.500000  10701.479761      1.019622         NaN        NaN
# std     14035.529381   6180.119770      0.143077         NaN        NaN
# min         1.000000      1.000000      1.000000         NaN        NaN
# 25%     12155.750000   5337.000000      1.000000         NaN        NaN
# 50%     24310.500000  10682.500000      1.000000         NaN        NaN
# 75%     36465.250000  16100.000000      1.000000         NaN        NaN
# max     48620.000000  21350.000000      4.000000         NaN        NaN
#
#           unit_price   total_price pizza_size pizza_category  \
# ...

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             1
# pizza_name_id        1
# quantity             1
# order_date           1
# order_time           1
# unit_price           1
# total_price          1
# pizza_size           1
# pizza_category       1
# pizza_ingredients    1
# pizza_name           1
# dtype: int64

# %%
print("Shape:", df.shape)
print(df[['pizza_id', 'order_id', 'quantity']].dtypes)
# Out:
# Shape: (24537, 12)
# pizza_id      int64
# order_id    float64
# quantity    float64
# dtype: object

# %%
print("pizza_id unique decimals:", (df['pizza_id']% 1 !=0).sum())
# Out:
# pizza_id unique decimals: 0

# %%
print("order_id unique decimals:", (df['order_id']% 1 !=0).sum())
print("quantity unique decimals:", (df['quantity']% 1 !=0).sum())
# Out:
# order_id unique decimals: 1
# quantity unique decimals: 1

# %%
df['pizza_id'] = df['pizza_id'].fillna(0)
df['order_id'] = df['order_id'].fillna(0)
df['quantity'] = df['quantity'].fillna(0)


df['pizza_id'] = df['pizza_id'].astype(int)
df['order_id'] = df['order_id'].astype(int)
df['quantity'] = df['quantity'].astype(int)

# %%
print(df[['pizza_id','order_id','quantity']].dtypes)
print(df[['pizza_id','order_id','quantity']].head())
# Out:
# pizza_id      int64
# order_id    float64
# quantity    float64
# dtype: object
#    pizza_id  order_id  quantity
# 0         1       1.0       1.0
# 1         2       2.0       1.0
# 2         3       2.0       1.0
# 3         4       2.0       1.0
# 4         5       2.0       1.0

# %%
print(df['order_date'].head(10))
print(df['order_date'].dtype)
# Out:
# 0    1/1/2015
# 1    1/1/2015
# 2    1/1/2015
# 3    1/1/2015
# 4    1/1/2015
# 5    1/1/2015
# 6    1/1/2015
# 7    1/1/2015
# 8    1/1/2015
# 9    1/1/2015
# Name: order_date, dtype: object
# object

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=False)

print(df['order_date'].head(5))
print(df['order_date'].dtype)
# Out:
# 0   2015-01-01
# 1   2015-01-01
# 2   2015-01-01
# 3   2015-01-01
# 4   2015-01-01
# Name: order_date, dtype: datetime64[ns]
# datetime64[ns]

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=False)

print(df['order_date'].dtype)
# Out:
# datetime64[ns]

# %%
print(df['pizza_id'].isnull().sum())
print(df['order_id'].isnull().sum())
print(df['quantity'].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
print(df[df['order_id'].isnull()])
# Out:
#        pizza_id  order_id pizza_name_id  quantity order_date order_time  \
# 24536     24537       NaN           NaN       NaN        NaN        NaN
#
#        unit_price  total_price pizza_size pizza_category pizza_ingredients  \
# 24536         NaN          NaN        NaN            NaN               NaN
#
#       pizza_name
# 24536        NaN

# %%
df = df.dropna(subset=['pizza_id', 'order_id', 'quantity'])
print("Rows after dropping NaN:", len(df))
# Out:
# Rows after dropping NaN: 24536

# %%
df['order_date'] = df['order_date'].dt.strftime('%Y-%m-%d')

print(df['order_date'].head(5))
# Out:
# 0    2015-01-01
# 1    2015-01-01
# 2    2015-01-01
# 3    2015-01-01
# 4    2015-01-01
# Name: order_date, dtype: object

# %%
print(df['order_date'].dtype)
# Out:
# object

# %%
print(df['order_date'].dtype)
# Out:
# object

# %%
print(df['order_date'].head(5))
print(df['order_date'].tail(5))
# Out:
# 0    2015-01-01
# 1    2015-01-01
# 2    2015-01-01
# 3    2015-01-01
# 4    2015-01-01
# Name: order_date, dtype: object
# 24531    2015-06-30
# 24532    2015-06-30
# 24533    2015-06-30
# 24534    2015-06-30
# 24535    2015-06-30
# Name: order_date, dtype: object

# %%
print("Earliest date:", df['order_date'].max())
print("Earliest date:", df['order_date'].min())
# Out:
# Earliest date: 2015-12-06
# Earliest date: 2015-01-01

# %%
print(df['order_time'].head(5))
print(df['order_time'].dtype)
# Out:
# 0    11:38:36
# 1    11:57:40
# 2    11:57:40
# 3    11:57:40
# 4    11:57:40
# Name: order_time, dtype: object
# object

# %%
df['order_time'] = pd.to_datetime(df['order_time'], format='%H:%M:%S')
print(df['order_time'].dtype)

df['order_time'] = df['order_time'].dt.strftime('%H:%M:%S')

print(df['order_time'].head(5))
print(df['order_time'].dtype)
# Out:
# datetime64[ns]
# 0    11:38:36
# 1    11:57:40
# 2    11:57:40
# 3    11:57:40
# 4    11:57:40
# Name: order_time, dtype: object
# object

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=False)
print(df['order_date'].dtype)
# Out:
# datetime64[ns]

# %%
df['month'] = df['order_date'].dt.month

print(df['month'].head(5))
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: month, dtype: int32

# %%
df['month_name'] = df['order_date'].dt.month_name()
print(df['month_name'].head(5))
# Out:
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January
# Name: month_name, dtype: object

# %%
df['day_of_week'] = df['order_date'].dt.day_name()
print(df['day_of_week'].head(5))
# Out:
# 0    Thursday
# 1    Thursday
# 2    Thursday
# 3    Thursday
# 4    Thursday
# Name: day_of_week, dtype: object

# %%
df['quarter'] = df['order_date'].dt.quarter
print(df['quarter'].head(5))
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: quarter, dtype: int32

# %%
df['order_time'] = pd.to_datetime(df['order_time'], format='%H:%M:%S')
df['hour'] = df['order_time'].dt.hour

print(df['hour'].head(5))
# Out:
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: hour, dtype: int32

# %%
print(df[['order_date', 'month', 'month_name', 'day_of_week', 'quarter', 'hour']].head(5))
# Out:
#   order_date  month month_name day_of_week  quarter  hour
# 0 2015-01-01      1    January    Thursday        1    11
# 1 2015-01-01      1    January    Thursday        1    11
# 2 2015-01-01      1    January    Thursday        1    11
# 3 2015-01-01      1    January    Thursday        1    11
# 4 2015-01-01      1    January    Thursday        1    11

# %%
print(df.columns.tolist())
# Out:
# ['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size', 'pizza_category', 'pizza_ingredients', 'pizza_name', 'month', 'month_name', 'day_of_week', 'quarter', 'Hour', 'hour']

# %%
df = df.drop(columns=['pizza_name_id'])

# %%
print(df.columns.tolist())
# Out:
# ['pizza_id', 'order_id', 'quantity', 'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size', 'pizza_category', 'pizza_ingredients', 'pizza_name', 'month', 'month_name', 'day_of_week', 'quarter', 'Hour', 'hour']

# %%
print("Shape  :", df.shape)
print("Nulls  :", df.isnull().sum().sum())
print("Columns:", df.columns.tolist())
df.head()
# Out:
# Shape  : (24536, 17)
# Nulls  : 0
# Columns: ['pizza_id', 'order_id', 'quantity', 'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size', 'pizza_category', 'pizza_ingredients', 'pizza_name', 'month', 'month_name', 'day_of_week', 'quarter', 'Hour', 'hour']
#    pizza_id  order_id  quantity order_date          order_time  unit_price  \
# 0         1         1         1 2015-01-01 1900-01-01 11:38:36       13.25
# 1         2         2         1 2015-01-01 1900-01-01 11:57:40       16.00
# 2         3         2         1 2015-01-01 1900-01-01 11:57:40       18.50
# 3         4         2         1 2015-01-01 1900-01-01 11:57:40       20.75
# 4         5         2         1 2015-01-01 1900-01-01 11:57:40       16.00
#
#    total_price pizza_size pizza_category  \
# 0        13.25          M        Classic
# 1        16.00          M        Classic
# 2        18.50          L         Veggie
# 3        20.75          L        Supreme
# ...

# %%
df['order_time'] = pd.to_datetime(df['order_time'], format='%H:%M:%S')

df['hour'] = df['order_time'].dt.hour

df['order_time'] = df['order_time'].dt.strftime('%H:%M:%S')

print(df[['order_time', 'hour']].head(5))
print(df['order_time'].dtype)
# Out:
#   order_time  hour
# 0   11:38:36    11
# 1   11:57:40    11
# 2   11:57:40    11
# 3   11:57:40    11
# 4   11:57:40    11
# object

# %%
df.head()
# Out:
#    pizza_id  order_id  quantity order_date order_time  unit_price  \
# 0         1         1         1 2015-01-01   11:38:36       13.25
# 1         2         2         1 2015-01-01   11:57:40       16.00
# 2         3         2         1 2015-01-01   11:57:40       18.50
# 3         4         2         1 2015-01-01   11:57:40       20.75
# 4         5         2         1 2015-01-01   11:57:40       16.00
#
#    total_price pizza_size pizza_category  \
# 0        13.25          M        Classic
# 1        16.00          M        Classic
# 2        18.50          L         Veggie
# 3        20.75          L        Supreme
# 4        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# ...

# %%
df.to_csv('pizza_sales_cleaned.csv', index=False)
print("File saved successfully!")
# Out:
# File saved successfully!

# %%
df = df.drop(columns=['pizza_ingredients'])

# %%
df.to_csv('pizza_sales_cleaned.csv', index=False)
print("File saved successfully!")
# Out:
# File saved successfully!

# %%
df['calculated_price'] = df['unit_price'] * df['quantity']

mismatch = df[df['calculated_price'] != df['total_price']]
print("Mismatches:", len(mismatch))
print(mismatch[['pizza_name', 'quantity', 'unit_price', 'total_price', 'calculated_price']].head(10))
# Out:
# Mismatches: 0
# Empty DataFrame
# Columns: [pizza_name, quantity, unit_price, total_price, calculated_price]
# Index: []

# %%
df.head()
# Out:
#    pizza_id  order_id  quantity order_date order_time  unit_price  \
# 0         1         1         1 2015-01-01   11:38:36       13.25
# 1         2         2         1 2015-01-01   11:57:40       16.00
# 2         3         2         1 2015-01-01   11:57:40       18.50
# 3         4         2         1 2015-01-01   11:57:40       20.75
# 4         5         2         1 2015-01-01   11:57:40       16.00
#
#    total_price pizza_size pizza_category                 pizza_name  month  \
# 0        13.25          M        Classic         The Hawaiian Pizza      1
# 1        16.00          M        Classic   The Classic Deluxe Pizza      1
# 2        18.50          L         Veggie      The Five Cheese Pizza      1
# 3        20.75          L        Supreme  The Italian Supreme Pizza      1
# 4        16.00          M         Veggie         The Mexicana Pizza      1
#
#   month_name day_of_week  quarter  Hour  hour  calculated_price
# ...

# %%
df = df.drop(columns=['total_price'])

# %%
df = df.rename(columns={'calculated_price': 'total_price'})
print(df.columns.tolist())
# Out:
# ['pizza_id', 'order_id', 'quantity', 'order_date', 'order_time', 'unit_price', 'pizza_size', 'pizza_category', 'pizza_name', 'month', 'month_name', 'day_of_week', 'quarter', 'Hour', 'hour', 'total_price']

# %%
df.head()
# Out:
#    pizza_id  order_id  quantity order_date order_time  unit_price pizza_size  \
# 0         1         1         1 2015-01-01   11:38:36       13.25          M
# 1         2         2         1 2015-01-01   11:57:40       16.00          M
# 2         3         2         1 2015-01-01   11:57:40       18.50          L
# 3         4         2         1 2015-01-01   11:57:40       20.75          L
# 4         5         2         1 2015-01-01   11:57:40       16.00          M
#
#   pizza_category                 pizza_name  month month_name day_of_week  \
# 0        Classic         The Hawaiian Pizza      1    January    Thursday
# 1        Classic   The Classic Deluxe Pizza      1    January    Thursday
# 2         Veggie      The Five Cheese Pizza      1    January    Thursday
# 3        Supreme  The Italian Supreme Pizza      1    January    Thursday
# 4         Veggie         The Mexicana Pizza      1    January    Thursday
#
#    quarter  Hour  hour  total_price
# ...

# %%
df.to_csv('pizza_sales_cleaned2.csv', index=False)
print("Saved ✅")
# Out:
# Saved ✅

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df_raw = pd.read_csv('pizza_sales.csv')

# Check rows where quantity > 1
print(df_raw[df_raw['quantity'] > 1][['pizza_name', 'quantity', 'unit_price', 'total_price']].head(10))
# Out:
#                        pizza_name  quantity  unit_price  total_price
# 48        The Mediterranean Pizza       2.0       16.00        32.00
# 183       The Spicy Italian Pizza       3.0       20.75        62.25
# 211    The Barbecue Chicken Pizza       2.0       20.75        41.50
# 222               The Greek Pizza       2.0       16.00        32.00
# 245            The Hawaiian Pizza       2.0       10.50        21.00
# 341    The Barbecue Chicken Pizza       3.0       16.75        50.25
# 444            The Big Meat Pizza       2.0       12.00        24.00
# 456     The Chicken Alfredo Pizza       2.0       20.75        41.50
# 611  The California Chicken Pizza       2.0       16.75        33.50
# 612     The Chicken Alfredo Pizza       2.0       16.75        33.50

# %%
print("Total Revenue:", round(df['total_price'].sum(), 2))
# Out:
# Total Revenue: 413222.4

# %%
df['total_price'] = df['unit_price'] * df['quantity']
print("After fix:", round(df['total_price'].sum(), 2))
# Out:
# After fix: 413222.4

# %%
df = pd.read_csv('pizza_sales.csv')
print("Total Revenue:", round(df['total_price'].sum(), 2))

df['total_price'].sum()
# Out:
# Total Revenue: 817860.05
# np.float64(817860.05)

# %%
df.to_csv('pizza_sales_cleaned.csv', index=False)
print("Saved ✅")
# Out:
# Saved ✅

# %%
df.to_csv('pizza_sales_cleaned.csv', index=False)
print("Saved ✅")
# Out:
# Saved ✅
